# %%
import pandas             as pd
import numpy              as np
import matplotlib.pyplot  as plt
import seaborn            as sns
from sklearn.linear_model import LinearRegression

# Residuais
from yellowbrick.regressor import ResidualsPlot

# %%
data = pd.read_csv('pesquisaIMT.csv')

data.shape
# Out:
# (289, 26)

# %%
data.head()
# Out:
#    Idade  Irmaos  Altura Genero Curso Exterior  ABC Transp  Distancia  \
# 0     20       0     175      M    PM      SIM  NAO  Carro       24.0
# 1     24       0     170      M    EN      SIM  NAO  Carro       20.0
# 2     21       2     164      F    CA      SIM  NAO  Carro       28.0
# 3     21       1     173      M    CA      SIM  NAO  Carro       10.0
# 4     23       1     175      M    CM      SIM  SIM  Carro       20.0
#
#    Ida_IMT  ...  Fam_Populacao  Fam_Estimador  Fam_Estimativa  Fam_Media  \
# 0     60.0  ...              3              1               2          3
# 1     45.0  ...              3              2               3          3
# 2     60.0  ...              3              2               2          3
# 3     30.0  ...              3              1               2          3
# 4     60.0  ...              3              2               2          3
#
#    Fam_Var  Fam_Quartil  Fam_Percentil  Fam_Distribuicao  Fam_IC  \
# ...

# %%
sns.pairplot(data)
plt.show()

# NAO RODAR ESSA LINHA

# GERA UM GRAFICO PARA TODAS AS CATEGORIAS!!

# %%
print(['Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'crest', 'crest_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'flare', 'flare_r', 'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_heat', 'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'hot', 'hot_r', 'hsv', 'hsv_r', 'icefire', 'icefire_r', 'inferno', 'inferno_r', 'jet', 'jet_r', 'magma', 'magma_r', 'mako', 'mako_r', 'nipy_spectral', 'nipy_spectral_r', 'ocean', 'ocean_r', 'pink', 'pink_r', 'plasma', 'plasma_r', 'prism', 'prism_r', 'rainbow', 'rainbow_r', 'rocket', 'rocket_r', 'seismic', 'seismic_r', 'spring', 'spring_r', 'summer', 'summer_r', 'tab10', 'tab10_r', 'tab20', 'tab20_r', 'tab20b', 'tab20b_r', 'tab20c', 'tab20c_r', 'terrain', 'terrain_r', 'turbo', 'turbo_r', 'twilight', 'twilight_r', 'twilight_shifted', 'twilight_shifted_r', 'viridis', 'viridis_r', 'vlag', 'vlag_r', 'winter', 'winter_r'])
# PALETTES
# Out:
# ['Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'crest', 'crest_r', 'cubehelix', 'cubehelix
# ...

# %%
# Variavel Independente
X = np.array(data['Ida_IMT'])

# Variavel Dependente
y = np.array(data['Volta_IMT'])

# Correlacao
correlacao = np.corrcoef(X, y)

print(f'X: {X}\n')
print(f'y: {y}\n')
print(f'Correlacao: {correlacao}')
# Out:
# X: [ 60.   45.   60.   30.   60.   20.   35.   40.   35.   60.   10.   55.
#   50.   30.   90.   20.   30.   25.   35.   30.   40.   30.   47.5   5.
#   10.   40.   40.   90.   60.   50.   80.    5.   25.   90.   25.   35.
#  120.   40.   60.   60.   40.   90.   40.   40.   10.   60.   60.   30.
#   80.   50.   50.   10.   50.   30.   90.  120.   40.   50.   50.    7.
#   27.5  45.    7.   30.   25.   60.   27.5  60.   25.   20.   25.   75.
#   10.   25.   30.   40.   60.   20.   20.   70.   20.   20.   10.   60.
#   70.   16.   60.   30.   18.   25.   48.   90.   75.   23.   50.   60.
#    7.   40.   35.   60.   40.   70.   20.   50.   90.   20.   25.   50.
#   60.  150.  105.   40.   30.   45.  105.  120.   15.   90.   90.   10.
#   60.   60.   60.   10.   15.   10.   60.  100.   50.   50.   40.   60.
#   40.   60.   60.  105.   25.   40.   30.   15.   70.   10.   60.   25.
#   90.   90.   40.   60.   45.  100.   60.   60.   15.  100.   20.   30.
# ...

# %%
X = X.reshape(-1, 1)
X
# Out:
# array([[ 60. ],
#        [ 45. ],
#        [ 60. ],
#        [ 30. ],
#        [ 60. ],
#        [ 20. ],
#        [ 35. ],
#        [ 40. ],
#        [ 35. ],
#        [ 60. ],
#        [ 10. ],
#        [ 55. ],
#        [ 50. ],
#        [ 30. ],
#        [ 90. ],
#        [ 20. ],
#        [ 30. ],
#        [ 25. ],
#        [ 35. ],
#        [ 30. ],
#        [ 40. ],
#        [ 30. ],
#        [ 47.5],
#        [  5. ],
#        [ 10. ],
#        [ 40. ],
#        [ 40. ],
#        [ 90. ],
#        [ 60. ],
#        [ 50. ],
#        [ 80. ],
#        [  5. ],
#        [ 25. ],
#        [ 90. ],
#        [ 25. ],
#        [ 35. ],
#        [120. ],
#        [ 40. ],
#        [ 60. ],
#        [ 60. ],
#        [ 40. ],
#        [ 90. ],
#        [ 40. ],
#        [ 40. ],
#        [ 10. ],
#        [ 60. ],
#        [ 60. ],
#        [ 30. ],
#        [ 80. ],
#        [ 50. ],
#        [ 50. ],
#        [ 10. ],
#        [ 50. ],
#        [ 30. ],
#        [ 90. ],
# ...

# %%
modelo = LinearRegression()
modelo.fit(X, y)
# Out:
# LinearRegression()

# %%
plt.scatter(X, y, marker = '.', color='black')
plt.title('Tempo de ida ao IMT x Tempo de volta do IMT')
plt.xlabel('Tempo de ida ao IMT (min)')
plt.ylabel('Tempo de Volta do IMT (min)')

plt.plot(X, modelo.predict(X), color='red')

# %%
modelo.predict([[100]])
# Out:
# array([102.07436994])

# %% [markdown]
# # **Visualizando residuais**

# %%
visualizar_residuais = ResidualsPlot(modelo)
visualizar_residuais.fit(X, y)

visualizar_residuais.poof()
# Out:
# <AxesSubplot:title={'center':'Residuals for LinearRegression Model'}, xlabel='Predicted Value', ylabel='Residuals'>

# %%
data.columns
# Out:
# Index(['Idade', 'Irmaos', 'Altura', 'Genero', 'Curso', 'Exterior', 'ABC',
#        'Transp', 'Distancia', 'Ida_IMT', 'Volta_IMT', 'Alimentacao',
#        'Estatistica', 'Ciencia_Dados', 'Fam_Parametro', 'Fam_Amostra',
#        'Fam_Populacao', 'Fam_Estimador', 'Fam_Estimativa', 'Fam_Media',
#        'Fam_Var', 'Fam_Quartil', 'Fam_Percentil', 'Fam_Distribuicao', 'Fam_IC',
#        'Fam_Teste_Hip'],
#       dtype='object')

# %% [markdown]
# # ***Altura dos estudadntes por idade***

# %%
sns.set_theme(style='darkgrid')
sns.catplot(x = data['Idade'], y = data['Altura'], data = data, palette='rocket')
plt.title('Idade x Altura')
plt.xlabel('Idade (anos)')
plt.ylabel('Altura (cm)')
plt.show()

# %% [markdown]
# # ***Altura dos estudantes por genero***

# %%
sns.set_theme(style="darkgrid")

sns.catplot(x = data['Genero'], y = data['Altura'], data = data, kind='swarm', palette='rocket')

plt.title('Genero x Altura')

plt.show()

# %% [markdown]
# # ***Idade dos estudantes***

# %%
sns.set_theme(style="darkgrid")

sns.countplot(x = 'Idade', data = data, palette='rocket');

# %% [markdown]
# # ***Meios de transporte dos estudantes***

# %%
sns.set_palette('Blues')

sns.countplot(y = 'Transp', data = data, palette='rocket')

plt.title('Meios de transporte')

plt.show()

# %% [markdown]
# # ***Alunos por curso***

# %%
sns.countplot(x = 'Curso', data = data, palette='rocket');

# %%
sns.stripplot(x = 'Genero', y = 'Curso', data = data, palette='rocket');

# %%
plt.subplot(2, 1, 1)
sns.lineplot(x = 'Idade', y = 'Altura', data = data)

plt.subplot(2, 1, 2)
sns.regplot(x = 'Idade', y = 'Altura', data = data)
# Out:
# <AxesSubplot:xlabel='Idade', ylabel='Altura'>

# %%
plt.subplot(2, 1, 1)
sns.boxplot(x = 'Idade', y = 'Altura', data = data)

plt.subplot(2, 1, 2)
sns.kdeplot(x = 'Idade', y = 'Altura', data = data)
# Out:
# <AxesSubplot:xlabel='Idade', ylabel='Altura'>

# %%
data.head()
# Out:
#    Idade  Irmaos  Altura Genero Curso Exterior  ABC Transp  Distancia  \
# 0     20       0     175      M    PM      SIM  NAO  Carro       24.0
# 1     24       0     170      M    EN      SIM  NAO  Carro       20.0
# 2     21       2     164      F    CA      SIM  NAO  Carro       28.0
# 3     21       1     173      M    CA      SIM  NAO  Carro       10.0
# 4     23       1     175      M    CM      SIM  SIM  Carro       20.0
#
#    Ida_IMT  ...  Fam_Populacao  Fam_Estimador  Fam_Estimativa  Fam_Media  \
# 0     60.0  ...              3              1               2          3
# 1     45.0  ...              3              2               3          3
# 2     60.0  ...              3              2               2          3
# 3     30.0  ...              3              1               2          3
# 4     60.0  ...              3              2               2          3
#
#    Fam_Var  Fam_Quartil  Fam_Percentil  Fam_Distribuicao  Fam_IC  \
# ...

# %%
data.corr()
# Out:
#                      Idade    Irmaos    Altura  Distancia   Ida_IMT  \
# Idade             1.000000  0.125215  0.010979  -0.058484 -0.112910
# Irmaos            0.125215  1.000000 -0.003165   0.094675  0.046646
# Altura            0.010979 -0.003165  1.000000   0.007910  0.025672
# Distancia        -0.058484  0.094675  0.007910   1.000000  0.607835
# Ida_IMT          -0.112910  0.046646  0.025672   0.607835  1.000000
# Volta_IMT        -0.149464  0.070165 -0.032116   0.653285  0.866654
# Alimentacao       0.054272  0.136293 -0.012506   0.159653  0.088036
# Estatistica       0.576225  0.016124  0.037005  -0.048810 -0.070608
# Ciencia_Dados     0.233538  0.003133  0.145826  -0.040688 -0.015152
# Fam_Parametro     0.325408 -0.029108  0.004884  -0.039745 -0.032048
# Fam_Amostra       0.325681  0.011491 -0.025616  -0.032287  0.001253
# Fam_Populacao     0.051327 -0.057791  0.060827   0.005297  0.033604
# Fam_Estimador     0.162397 -0.027620  0.054959  -0.015769 -0.007529
# ...

# %%
sns.heatmap(data.corr())
# Out:
# <AxesSubplot:>

# %%
data = data.drop(['Estatistica'], axis=1)

test_data = data.iloc[0:15, 0:15]
test_data
# Out:
#     Idade  Irmaos  Altura Genero Curso Exterior  ABC  Transp  Distancia  \
# 0      20       0     175      M    PM      SIM  NAO   Carro       24.0
# 1      24       0     170      M    EN      SIM  NAO   Carro       20.0
# 2      21       2     164      F    CA      SIM  NAO   Carro       28.0
# 3      21       1     173      M    CA      SIM  NAO   Carro       10.0
# 4      23       1     175      M    CM      SIM  SIM   Carro       20.0
# 5      21       1     170      M    CA      NAO  SIM   Carro        4.1
# 6      21       1     183      M    PM      SIM  NAO   Carro       12.0
# 7      24       0     183      M    PM      SIM  NAO   Carro       20.0
# 8      21       1     174      M    PM      SIM  NAO   Carro       20.0
# 9      21       2     165      F    PM      SIM  NAO  Onibus       24.0
# 10     21       1     185      M    PM      NAO  SIM    Trem        4.0
# 11     21       1     177      M    PM      SIM  NAO  Onibus       12.0
# ...

# %%
test_data.corr()
# Out:
#                       Idade        Irmaos    Altura  Distancia   Ida_IMT  \
# Idade          1.000000e+00 -4.190010e-01  0.039993   0.051881  0.226380
# Irmaos        -4.190010e-01  1.000000e+00 -0.581636   0.059415  0.027342
# Altura         3.999280e-02 -5.816362e-01  1.000000  -0.319437 -0.326222
# Distancia      5.188071e-02  5.941460e-02 -0.319437   1.000000  0.617715
# Ida_IMT        2.263804e-01  2.734241e-02 -0.326222   0.617715  1.000000
# Volta_IMT      2.433632e-01 -4.148699e-02 -0.053210   0.634412  0.873453
# Alimentacao    2.422185e-01  4.061892e-01 -0.675522  -0.085017  0.094225
# Ciencia_Dados  1.455179e-01  0.000000e+00  0.064744   0.165445  0.044088
# Fam_Parametro -2.256025e-16 -1.562407e-16  0.077494   0.090045 -0.402547
# Fam_Amostra    3.755316e-01 -2.383656e-01 -0.248845   0.064297  0.049533
#
#                Volta_IMT  Alimentacao  Ciencia_Dados  Fam_Parametro  \
# Idade           0.243363     0.242219   1.455179e-01  -2.256025e-16
# ...

# %%
sns.heatmap(test_data.corr())
# Out:
# <AxesSubplot:>
